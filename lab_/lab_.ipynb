# %% [markdown]
# # Lab_
# this file has been made to check some data features

# %% [markdown]
# ## Load_data

# %%
import pandas 
import os
from pathlib import Path

# %%
data_path = str(Path(__file__).parent.parent / '01_Data' / 'heart-disease.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data_path = str(Path(__file__).parent.psrent / '01_Data' / 'heart-disease.csv')
#
# NameError: name '__file__' is not defined
